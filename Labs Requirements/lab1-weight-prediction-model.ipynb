# %%
import math
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
# 0. Cargar los datos de estatura y peso
url = 'http://wiki.stat.ucla.edu/socr/index.php?title=SOCR_Data_Dinov_020108_HeightsWeights&oldid=12529'

height_weight_df = pd.read_html(url)[1][['Height(Inches)','Weight(Pounds)']]

# %%
# 1. Count records in the dataframe
print(height_weight_df.count())
# 2. Crear una regresion lineal con estatura como variable explicatoria y peso como variable explicada
reg = linear_model.LinearRegression()
# 3. Hallar el intercepto
intercepto = reg.fit(height_weight_df[['Height(Inches)']], height_weight_df[['Weight(Pounds)']])
# 4. Hacer la grafica
plt.scatter(height_weight_df['Height(Inches)'], height_weight_df['Weight(Pounds)'])
plt.plot(height_weight_df['Height(Inches)'], reg.predict(height_weight_df[['Height(Inches)']]), color='red', linewidth=2, label='Línea de regresión')
plt.xlabel('Height (Inches)')
plt.ylabel('Weight (Pounds)')
plt.title('Regresión Lineal de Peso vs. Estatura')
plt.legend()
plt.show()
# 5. Hallar correlacion y valor p
r, p = pearsonr(height_weight_df['Height(Inches)'], height_weight_df['Weight(Pounds)'])
# 6. Interpretar el valor p
print('El valor p es', p)
# Out:
# Height(Inches)    200
# Weight(Pounds)    200
# dtype: int64
# El valor p es 1.1029015151266403e-17

# %% [markdown]
# Como el valor de p es muy bajo, se puede decir que si existe una correlación entre ambas variables. Altura y Peso. Rechazando la hipotesis nula que dice que no existe correlación entre ambas variables.
